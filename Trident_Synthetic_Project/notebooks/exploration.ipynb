# %% [markdown]
# # Synthetic Time-Series Anomaly Detection
# This notebook explores the generated dataset and trains models.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/synthetic_timeseries.csv', parse_dates=['timestamp'])
df.head()
# Out:
#             timestamp  voltage  current   power     pf    freq  harmonics  \
# 0 2025-06-01 00:00:00  229.931   0.3688  84.795  0.980  49.995    0.00234
# 1 2025-06-01 00:01:00  230.505   0.3421  78.860  0.939  49.989    0.00924
# 2 2025-06-01 00:02:00  229.719   0.3179  73.033  0.956  49.982    0.01412
# 3 2025-06-01 00:03:00  230.299   0.3987  91.823  0.958  50.002    0.00515
# 4 2025-06-01 00:04:00  229.854   0.3371  77.484  0.987  50.000    0.01058
#
#    anomaly  power_ma_5  power_std_5  current_diff_1  power_pct_change_1
# 0        0    84.79500     0.000000          0.0000            0.000000
# 1        0    81.82750     4.196679         -0.0267           -0.069992
# 2        0    78.89600     5.881083         -0.0242           -0.073890
# 3        0    82.12775     8.052013          0.0808            0.257281
# 4        0    81.19900     7.275924         -0.0616           -0.156159

# %%
df[['power']].plot(figsize=(12,4))
plt.title('Power Time-Series')
plt.show()
